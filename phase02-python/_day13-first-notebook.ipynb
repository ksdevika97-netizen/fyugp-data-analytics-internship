# %%
# This notebook stores my personal details and calculates my age in months, days, and hours

# %%
name=input("Enter name")
age=int(input("Enter age"))
city=input("Enter city")

months=age*12
days=age*365
hours=age*24

print("My name is:",name)
print("My age is:",age)
print("My city is:",city)

print("My age in months:",months)
print("My age in days:",days)
print("My age in hours:",hours)
# Out:
# Enter name Devika
# Enter age 19
# Enter city Ernakulam
# My name is: Devika
# My age is: 19
# My city is: Ernakulam
# My age in months: 228
# My age in days: 6935
# My age in hours: 456

# %%
print( my age)
# Out:
#   Input In [4]
#     print( my age)
#               ^
# SyntaxError: invalid syntax
