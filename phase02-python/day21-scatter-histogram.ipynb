# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("SALE.csv")
# Scatter plot
plt.figure()
plt.scatter(df["Sales"], df["Profit"])
plt.title("Sales vs Profit")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.show()

# %%
#The scatter plot shows a  positive relationship between sales and profit, although the pattern is not consistent. There are several cases where high sales correspond to low or negative profit.

# %%
# Histogram
plt.figure()
plt.hist(df["Sales"], bins=20)
plt.title("Distribution of Sales")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %%
#The histogram shows that most sales values are concentrated at the lower range, with a few higher values. This indicates that the distribution is uneven and slightly skewed.
